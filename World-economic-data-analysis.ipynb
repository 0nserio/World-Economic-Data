# %% [markdown]
# # WORLD ECONOMIC DATA ANALYSIS

# %% [markdown]
# This is an overview of World economic data that comprises of Corruption, Cost of living, richest Countries, Unemployment and Tourism datasets. A look through key insights within the datasets to find relationships and trends.

# %% [markdown]
# # CORRUPTION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("/kaggle/input/world-economic-data/corruption.csv")
df
# Out:
#          country  annual_income  corruption_index
# 0        Denmark          68110                12
# 1        Finland          53660                12
# 2    New Zealand          45340                12
# 3         Norway          84090                15
# 4      Singapore          64010                15
# ..           ...            ...               ...
# 105        Yemen            670                84
# 106    Venezuela          13080                86
# 107      Somalia            450                87
# 108        Syria           1170                87
# 109  South Sudan            460                89
#
# [110 rows x 3 columns]

# %%
df.shape
# Out:
# (110, 3)

# %%
df.head()
# Out:
#        country  annual_income  corruption_index
# 0      Denmark          68110                12
# 1      Finland          53660                12
# 2  New Zealand          45340                12
# 3       Norway          84090                15
# 4    Singapore          64010                15

# %%
df['annual_income'].head(20)
# Out:
# 0     68110
# 1     53660
# 2     45340
# 3     84090
# 4     64010
# 5     58890
# 6     90360
# 7     56370
# 8     81110
# 9     51040
# 10    45380
# 11    54450
# 12    52210
# 13    48310
# 14    25970
# 15    64410
# 16    74520
# 17    56760
# 18    50510
# 19    42620
# Name: annual_income, dtype: int64

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of          country  annual_income  corruption_index
# 0        Denmark          68110                12
# 1        Finland          53660                12
# 2    New Zealand          45340                12
# 3         Norway          84090                15
# 4      Singapore          64010                15
# ..           ...            ...               ...
# 105        Yemen            670                84
# 106    Venezuela          13080                86
# 107      Somalia            450                87
# 108        Syria           1170                87
# 109  South Sudan            460                89
#
# [110 rows x 3 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           110 non-null    object
#  1   annual_income     110 non-null    int64
#  2   corruption_index  110 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.7+ KB

# %%
corr = df.sort_values(by='corruption_index', ascending=False)

# %%
corr.plot(x = 'country', y = 'corruption_index', kind='bar', title = "Corruption Index Per Country", rot = 90, figsize=(15, 20))
# Out:
# <Axes: title={'center': 'Corruption Index Per Country'}, xlabel='country'>

# %%
annual = df.sort_values(by='annual_income', ascending=False)

# %%
annual.plot(x = 'country', y = 'annual_income', kind='bar',title = "Annual Income per Country", rot = 90, figsize=(15, 20))
# Out:
# <Axes: title={'center': 'Annual Income per Country'}, xlabel='country'>

# %%
df.plot(x = 'corruption_index', y = 'annual_income', kind='scatter',title ="Correlation between Corruption Index and Annual Income", rot = 90, figsize=(20, 15))
# Out:
# <Axes: title={'center': 'Correlation between Corruption Index and Annual Income'}, xlabel='corruption_index', ylabel='annual_income'>

# %% [markdown]
# we see a negative correlation. There is a high annual income where there is less corruption.

# %% [markdown]
# # COST OF LIVING

# %%
cost_of_living = pd.read_csv('/kaggle/input/world-economic-data/cost_of_living.csv')
cost_of_living
# Out:
#             country  cost_index  monthly_income  purchasing_power_index
# 0           Bermuda       157.6            9712                   105.0
# 1       Switzerland       142.4            7530                    90.1
# 2    Cayman Islands       137.9            5281                    65.2
# 3            Israel       130.2            4130                    54.1
# 4           Iceland       128.0            5368                    71.5
# ..              ...         ...             ...                     ...
# 102           Burma        27.0              95                     6.0
# 103        Pakistan        25.8             125                     8.3
# 104      Kyrgyzstan        25.3              98                     6.6
# 105          Angola        23.0             148                    10.9
# 106      Tajikistan        22.8              96                     7.2
#
# [107 rows x 4 columns]

# %%
cost_of_living.head()
# Out:
#           country  cost_index  monthly_income  purchasing_power_index
# 0         Bermuda       157.6            9712                   105.0
# 1     Switzerland       142.4            7530                    90.1
# 2  Cayman Islands       137.9            5281                    65.2
# 3          Israel       130.2            4130                    54.1
# 4         Iceland       128.0            5368                    71.5

# %%
cost_of_living.shape
# Out:
# (107, 4)

# %%
cost_of_living.describe
# Out:
# <bound method NDFrame.describe of             country  cost_index  monthly_income  purchasing_power_index
# 0           Bermuda       157.6            9712                   105.0
# 1       Switzerland       142.4            7530                    90.1
# 2    Cayman Islands       137.9            5281                    65.2
# 3            Israel       130.2            4130                    54.1
# 4           Iceland       128.0            5368                    71.5
# ..              ...         ...             ...                     ...
# 102           Burma        27.0              95                     6.0
# 103        Pakistan        25.8             125                     8.3
# 104      Kyrgyzstan        25.3              98                     6.6
# 105          Angola        23.0             148                    10.9
# 106      Tajikistan        22.8              96                     7.2
#
# [107 rows x 4 columns]>

# %%
MI_cost_of_living = cost_of_living.sort_values(by = 'monthly_income', ascending = False)
MI_cost_of_living
# Out:
#          country  cost_index  monthly_income  purchasing_power_index
# 0        Bermuda       157.6            9712                   105.0
# 1    Switzerland       142.4            7530                    90.1
# 7         Norway       124.6            7008                    95.9
# 13    Luxembourg       113.1            6759                   101.8
# 10       Ireland       119.8            6210                    88.3
# ..           ...         ...             ...                     ...
# 104   Kyrgyzstan        25.3              98                     6.6
# 106   Tajikistan        22.8              96                     7.2
# 87      Tanzania        34.1              95                     4.7
# 102        Burma        27.0              95                     6.0
# 92        Zambia        31.7              87                     4.7
#
# [107 rows x 4 columns]

# %%
MI_cost_of_living.plot(x = 'country', y = 'monthly_income',title ="Cost of Living per Country", kind='bar', rot = 90, figsize=(20, 15))
# Out:
# <Axes: title={'center': 'Cost of Living per Country'}, xlabel='country'>

# %%
cost_of_living.plot(x = 'country', y = 'cost_index', title = "Cost Index per Country", kind='bar', rot = 90, figsize=(20, 15))
# Out:
# <Axes: title={'center': 'Cost Index per Country'}, xlabel='country'>

# %%
PPI_cost_of_living = cost_of_living.sort_values(by='purchasing_power_index', ascending=False)
PPI_cost_of_living
# Out:
#           country  cost_index  monthly_income  purchasing_power_index
# 31      Singapore        75.0            5334                   121.1
# 36          Qatar        71.4            4760                   113.6
# 0         Bermuda       157.6            9712                   105.0
# 13     Luxembourg       113.1            6759                   101.8
# 19  United States       100.0            5869                   100.0
# ..            ...         ...             ...                     ...
# 75          Benin        37.5             114                     5.2
# 92         Zambia        31.7              87                     4.7
# 87       Tanzania        34.1              95                     4.7
# 69        Lesotho        39.3             106                     4.6
# 42          Haiti        60.1             118                     3.4
#
# [107 rows x 4 columns]

# %%
PPI_cost_of_living.plot(x = 'country', y = 'purchasing_power_index', kind='bar', rot = 90, figsize=(20, 15))
# Out:
# <Axes: xlabel='country'>

# %%
cost_of_living.plot(x = 'monthly_income', y = 'cost_index', title = "Relation between Monthly Income and Cost Index", kind='scatter', rot = 90, figsize=(20, 15))
# Out:
# <Axes: title={'center': 'Relation between Monthly Income and Cost Index'}, xlabel='monthly_income', ylabel='cost_index'>

# %% [markdown]
# **The higher the salary, the higher the cost index.**

# %%
sns.heatmap(cost_of_living.corr())
# Out:
# /tmp/ipykernel_21/986996472.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cost_of_living.corr())
# <Axes: >

# %% [markdown]
# **The heat map shows how monthly income and the cost index interact, as well as monthly income and the purchasing power index.**

# %% [markdown]
# # RICHEST COUNTRIES

# %%
richest_countries = pd.read_csv('/kaggle/input/world-economic-data/richest_countries.csv')
richest_countries.head()
# Out:
#       country  gdp_per_capita
# 0  Luxembourg          134754
# 1   Singapore          116486
# 2     Ireland          106456
# 3       Qatar           93521
# 4     Bermuda           85192

# %%
richest_countries.shape
# Out:
# (50, 2)

# %%
richest_countries.describe
# Out:
# <bound method NDFrame.describe of            country  gdp_per_capita
# 0       Luxembourg          134754
# 1        Singapore          116486
# 2          Ireland          106456
# 3            Qatar           93521
# 4          Bermuda           85192
# 5           Norway           79201
# 6      Switzerland           77324
# 7            Macao           73802
# 8    United States           69288
# 9           Brunei           66620
# 10       Hong Kong           65973
# 11         Denmark           64651
# 12     Netherlands           63767
# 13          Sweden           59324
# 14         Belgium           58931
# 15         Austria           58427
# 16         Germany           57928
# 17         Iceland           57646
# 18       Australia           55807
# 19         Finland           55007
# 20          Canada           52085
# 21          France           50729
# 22  United Kingdom           49675
# 23    Saudi Arabia           49551
# 24           Malta           47714
# ...

# %%
richest_countries.plot(x = 'country', y = 'gdp_per_capita', kind='bar', rot = 90, figsize=(15, 20))
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# # UNEMPLOYMENT

# %%
dt = pd.read_csv('/kaggle/input/world-economic-data/unemployment.csv')
unemployment_data = pd.DataFrame(dt)
unemployment_data
# Out:
#                     country  unemployment_rate
# 0          Marshall Islands               36.0
# 1              South Africa               33.6
# 2                  Kiribati               30.6
# 3                    Kosovo               30.5
# 4            American Samoa               29.8
# ..                      ...                ...
# 59                Gibraltar                1.0
# 60                    Niger                0.8
# 61                 Cambodia                0.6
# 62                    Qatar                0.3
# 63  Cocos (Keeling) Islands                0.1
#
# [64 rows x 2 columns]

# %%
unemployment_data.info
# Out:
# <bound method DataFrame.info of                     country  unemployment_rate
# 0          Marshall Islands               36.0
# 1              South Africa               33.6
# 2                  Kiribati               30.6
# 3                    Kosovo               30.5
# 4            American Samoa               29.8
# ..                      ...                ...
# 59                Gibraltar                1.0
# 60                    Niger                0.8
# 61                 Cambodia                0.6
# 62                    Qatar                0.3
# 63  Cocos (Keeling) Islands                0.1
#
# [64 rows x 2 columns]>

# %%
unemployment_data.describe()
# Out:
#        unemployment_rate
# count          64.000000
# mean            7.823437
# std             8.806685
# min             0.100000
# 25%             2.700000
# 50%             5.000000
# 75%             8.250000
# max            36.000000

# %%
unemployment_data.plot(x = 'country', y = 'unemployment_rate', title = 'Unemployment Rate per Country', kind='bar', rot = 90, figsize=(15, 20))
# Out:
# <Axes: title={'center': 'Unemployment Rate per Country'}, xlabel='country'>
